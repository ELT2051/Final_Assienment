# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Talha Loai**
# Data Scientist

# %% [markdown]
# - *I am interested in data science because i want to manipulate Data*
# - *I am interested in data science because i want to work as Data Scientist*
# - *I am interested in data science because i want to gain a lot of money*

# %% [markdown]
# ### Addition of tow numbers

# %%
1+2
# Out:
# 3

# %% [markdown]
# 1. **Allah**
# 2. **Parents**
# 3. **anythin else**
#
#
#
# - kaja
# - jsj
# - jsfls
#
#
# [My_linkedIn](https://www.linkedin.com/in/talha-loai-65bba3198/)
